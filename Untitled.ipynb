# %%
import pandas as pd
df = pd.read_excel('Data Analyst - Test Data.xlsx')
df
# Out:
#                                                  Review       date  \
# 0     I was very impressed with the resort.\n Great ... 2019-08-20
# 1     The rooms were nice the outside needs work als... 2019-08-20
# 2     Great location! I have stayed at this hotel on... 2019-08-20
# 3     The hotel was adequate for my stay. The strips... 2019-08-20
# 4     Great location, room was large and spacious. P... 2019-08-19
# ...                                                 ...        ...
# 6443  ·the staff were all so friendly. frank, the ch... 2019-07-12
# 6444         ·the internet barely worked or didn't work 2019-07-12
# 6445  ·the location was great.\n \n \n \n \n ·the be... 2019-07-10
# 6446  ·we were early for check in and the staff was ... 2019-07-10
# 6447  ·staff, free coffee, location and activities.\... 2019-07-10
#
#                       Location
# 0                    Sebastian
# 1                  Los Angeles
# 2                      Georgia
# 3                          NaN
# ...

# %%
df.head()
# Out:
#                                               Review       date     Location
# 0  I was very impressed with the resort.\n Great ... 2019-08-20    Sebastian
# 1  The rooms were nice the outside needs work als... 2019-08-20  Los Angeles
# 2  Great location! I have stayed at this hotel on... 2019-08-20      Georgia
# 3  The hotel was adequate for my stay. The strips... 2019-08-20          NaN
# 4  Great location, room was large and spacious. P... 2019-08-19  Palm Harbor

# %%
#Now first we have clean the data or can say handle Null

# %%
df.isnull().sum()
# Out:
# Review        55
# date           0
# Location    4737
# dtype: int64

# %%
df2 = df.dropna()
df2.isnull().sum()
# Out:
# Review      0
# date        0
# Location    0
# dtype: int64

# %%
df2.head(10)
# Out:
#                                                Review       date      Location
# 0   I was very impressed with the resort.\n Great ... 2019-08-20     Sebastian
# 1   The rooms were nice the outside needs work als... 2019-08-20   Los Angeles
# 2   Great location! I have stayed at this hotel on... 2019-08-20       Georgia
# 4   Great location, room was large and spacious. P... 2019-08-19   Palm Harbor
# 10  Very clean and friendly and I love the locatio... 2019-08-19    California
# 15  Very nice and quiet and clean rooms. \n We wil... 2019-08-19       Redding
# 24  The room did not seem clean. There was some so... 2019-08-18  Jacksonville
# 29  En general excelente. Fantástica situación\n D... 2019-08-17        España
# 31  Les chambres familiales sont pratiques (nous é... 2019-08-17      Montréal
# 38  Enjoyed our stay! Staff was welcoming and frie... 2019-08-16     La quinta

# %%
#now we have to reset the data indexing

# %%
df2.reset_index(drop=True, inplace=True)
df2.head(15)
# Out:
#                                                Review       date  \
# 0   I was very impressed with the resort.\n Great ... 2019-08-20
# 1   The rooms were nice the outside needs work als... 2019-08-20
# 2   Great location! I have stayed at this hotel on... 2019-08-20
# 3   Great location, room was large and spacious. P... 2019-08-19
# 4   Very clean and friendly and I love the locatio... 2019-08-19
# 5   Very nice and quiet and clean rooms. \n We wil... 2019-08-19
# 6   The room did not seem clean. There was some so... 2019-08-18
# 7   En general excelente. Fantástica situación\n D... 2019-08-17
# 8   Les chambres familiales sont pratiques (nous é... 2019-08-17
# 9   Enjoyed our stay! Staff was welcoming and frie... 2019-08-16
# 10  Well kept up, but where was my complimentary b... 2019-08-15
# 11  propreté impeccable. chambre refaite tous les ... 2019-08-15
# 12  Sent my parents on an anniversary trip, They w... 2019-08-15
# ...

# %%
#now we export the data and let's go to make insights!

# %%
df2.to_csv('Clean_Data.csv')

# %%
df2.to_excel('Clean_Data.xlxs', sheet_name = 'Task Data')b
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:1144, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1143 try:
# -> 1144     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1145     if engine == "auto":
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_config/config.py:263, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     262 def __call__(self, *args, **kwds) -> T:
# --> 263     return self.__func__(*args, **kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_config/config.py:135, in _get_option(pat, silent)
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     137     # walk the nested dict
#
# ...
